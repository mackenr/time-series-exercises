Infer Meaningful Info' from Data. Data Scientist in similar definitions.&
&
&
Stephen Salas&
Stephen Salas&
&
&
Steve Newton&
&
&
Steven Garis&
Steven Garis&
Data Analyst at Earth Class Mail | Ada&
&
&
Symeon White&
Symeon White&
Data Scientist&
&
&
Tarrence Nichols&
Tarrence Nichols&
&
&
Tim Keriazes&
Tim Keriazes&
&
&
Tim Sotirhos&
Tim Sotirhos&
&
&
Trevor Esparza&
Trevor Esparza&
Web Development Student-Elixir&
&
&
Tyler Applegate&
Tyler Applegate&
DS Student, Florence Cohort&
&
&
Veronica Reyes&
Veronica F Reyes&
Germain Student at CodeUp&
&
&
Vincent Banuelos&
Vincent Banuelos&
&
&
wenliang sun&
wenliang sun&
&
&
Xavier Carter&
Xavier Carter&
Data Science Alumni, Florence Cohort&
&
&
Yongliang Shi&
Yongliang Shi&
&
&
Yvette Ibarra&
Yvette Ibarra&
&
&
Yvonne King&
Yvonne King&
&
&
Zach Stufflebeme&
Zach Stufflebeme&
'''

# %%
classmates=classmates.replace('\n','')
classmates=classmates.strip()
classmates=classmates.split('&')




for i in range(1, len(classmates)):
    if classmates[i] == classmates[i-1]:
         classmates[i]='del'





listtodel=['Data','Associate','Financial','Student','Application','Sr','Jr','II','III','(he/him)','(she/her)','(they/she)', 'Sr.','Jr.']
lower=[x.lower() for x in listtodel]

upper=[x.upper() for x in listtodel]

listtodel.extend(lower)
listtodel.extend(upper)

classmates= [j.split() for j in [x for x in classmates if all(x !=y for y in ['','del'])]]

for i in range(1, len(classmates)):
    a=classmates[i]
    b=classmates[i-1]
    complist=[]
    complist.append(any([a[0] ==y for y in listtodel]))
    complist.append(any([len(a)>3,len(a)<2]))
    
    if a[0] == b[0]:
        if len(a) > len(b):
            b='del'
        else:
            a='del'
    elif any(complist):
        a='del'
    classmates[i]=a
    classmates[i-1]=b
 


classmates= [' '.join(x) for x in classmates if all(x !=y for y in ['','del'])]


classmates=[x.split() for x in classmates]






for i in classmates:
    for x in i:
        if any([x==i for i in listtodel]):
           i.remove(x)
           classmates=classmates
    


classmates= [' '.join(x) for x in classmates if all(x !=y for y in ['','del'])]

import pandas as pd



classmates=str(classmates)

classmates.strip("'")
classmates=str(classmates)
classmates=classmates.replace(',',',\n')

classmates='\n'.join(classmates)


import os






classmates=classmates.replace('\n','')
classmates=classmates.strip()

classmates=classmates.split('&')




for i in range(1, len(classmates)):
    if classmates[i] == classmates[i-1]:
         classmates[i]='del'





listtodel=['Data','Associate','Financial','Student','Application','Sr','Jr','II','III','(he/him)','(she/her)','(they/she)', 'Sr.','Jr.','Ada','DS','{Ada}','(he/him)','{Florence}','Finishing','{Bayes}','Innis','#ada','DS Alumnus']
lower=[x.lower() for x in listtodel]

upper=[x.upper() for x in listtodel]

listtodel.extend(lower)
listtodel.extend(upper)

# %%
classmates= [j.split() for j in [x for x in classmates if all(x !=y for y in ['','del'])]]

for i in range(1, len(classmates)):
    a=classmates[i]
    b=classmates[i-1]
    complist=[]
    complist.append(any([a[0] ==y for y in listtodel]))
    complist.append(any([len(a)>3,len(a)<2]))
    
    if a[0] == b[0]:
        if len(a) > len(b):
            b='del'
        else:
            a='del'
    elif any(complist):
        a='del'
    elif any([a[-1] ==y for y in listtodel]):
        print(a.pop(a[-1]))

    classmates[i]=a
    classmates[i-1]=b
    display(a)

# %%
classmates= [' '.join(x) for x in classmates if all(x !=y for y in ['','del'])]

# classmates

# %%
# classmates=[x.split() for x in classmates]





newclass=[]
for x in classmates:
    # for x in i:
       
        if any([x==i for i in listtodel]):
           i.remove(x)
        x=x.strip()
        x=x.strip("'")
        x=x.replace('[','')
        x=x.replace(']','')
      
        x=x.replace("'",'')
        x=x.lower()
        # print(f"x:{x}\n")
        newclass.append([x])
        

newclass=str(newclass).split(',')
newclass=[x.replace('[','') for x in newclass]
newclass=[x.replace(']','') for x in newclass]
newclass
# Out:
# ["'adam gomez",
#  ' adam krull',
#  ' adam talbot',
#  ' addisalem kemal',
#  ' aj martinez',
#  ' abdiel martinez llanes',
#  ' alberto puentes',
#  ' alec hartman',
#  ' alejandro garcia',
#  ' alexia garces',
#  ' alicia g',
#  ' amanda gomez',
#  ' andrew king',
#  ' andrew rachuig',
#  ' angel i. gomez',
#  ' anna vu',
#  ' anthony straine',
#  ' arsene boundaone',
#  ' austin aranda',
#  ' barbara marques',
#  ' ben smith',
#  ' beth',
#  ' bethany t.',
#  ' bibek mainali',
#  ' brad gauvin',
#  ' braeden wright',
#  ' innis cohort',
#  ' brandi reger',
#  ' brandon martinez',
#  ' brandon bryant',
#  ' brandyn waterman',
#  ' brent schriver',
#  ' brian clements',
#  ' brooke holyoak',
#  ' caitlyn carney',
#  ' cameron taylor',
#  ' cari holmes',
#  ' carl griffin',
#  ' carolyn davis',
#  ' cayt schlichting',
#  ' chad hackney',
#  ' charles atchison',
#  ' chase thompson',
#  ' chenchen feng',
#  ' chloe whitaker',
#  ' christopher logan ortiz',
#  ' chris everts',
# ...

# %%
class1=[]
for i in range(0,len(newclass)):
    if i%2!=0:
        
        class1.append(newclass[i-1]+' '+newclass[i])



class1
# Out:
# ["'adam gomez  adam krull",
#  ' adam talbot  addisalem kemal',
#  ' aj martinez  abdiel martinez llanes',
#  ' alberto puentes  alec hartman',
#  ' alejandro garcia  alexia garces',
#  ' alicia g  amanda gomez',
#  ' andrew king  andrew rachuig',
#  ' angel i. gomez  anna vu',
#  ' anthony straine  arsene boundaone',
#  ' austin aranda  barbara marques',
#  ' ben smith  beth',
#  ' bethany t.  bibek mainali',
#  ' brad gauvin  braeden wright',
#  ' innis cohort  brandi reger',
#  ' brandon martinez  brandon bryant',
#  ' brandyn waterman  brent schriver',
#  ' brian clements  brooke holyoak',
#  ' caitlyn carney  cameron taylor',
#  ' cari holmes  carl griffin',
#  ' carolyn davis  cayt schlichting',
#  ' chad hackney  charles atchison',
#  ' chase thompson  chenchen feng',
#  ' chloe whitaker  christopher logan ortiz',
#  ' chris everts  john rosenberger',
#  ' chris teceno  christian freeman',
#  ' christopher mayorga  cindy villanueva',
#  ' cody clonts  corey solitaire',
# ...

# %%
classmates= [' '.join(x) for x in classmates if all(x !=y for y in ['','del'])]

# %%
import pandas as pd



classmates=str(classmates)

classmates=classmates.strip("'")
classmates=str(classmates)
classmates=classmates.replace(',',',\n')

classmates=''.join(classmates)
classmates=classmates.replace(" ' ",'')
classmates=str(classmates)
classmates=classmates.replace("[",'')
classmates=classmates.replace("]",'')
classmates=classmates.replace('"','')
classmates=classmates.replace("'",'')
classmates=classmates.replace(",,",'\n')


classmates=classmates.split('\n')


classmates=[i.replace(" [",'') for i in classmates]
classmates=[i.replace(" ]",'') for i in classmates]
classmates=[i.strip() for i in classmates]

classmates=[i.replace(" ' ",'') for i in classmates]
classmates=[i.split(' ')for i in classmates]



            






classmates
# Out:
# [['A', 'd', 'a', 'm', '', '', 'G', 'o', 'm', 'e', 'z,'],
#  ['A', 'd', 'a', 'm', '', '', 'K', 'r', 'u', 'l', 'l,'],
#  ['A', 'd', 'a', 'm', '', '', 'T', 'a', 'l', 'b', 'o', 't,'],
#  ['a',
#   'd',
#   'd',
#   'i',
#   's',
#   'a',
#   'l',
#   'e',
#   'm',
#   '',
#   '',
#   'k',
#   'e',
#   'm',
#   'a',
#   'l,'],
#  ['A', 'J', '', '', 'M', 'a', 'r', 't', 'i', 'n', 'e', 'z,'],
#  ['A',
#   'b',
#   'd',
#   'i',
#   'e',
#   'l',
#   '',
#   '',
#   'M',
#   'a',
#   'r',
#   't',
#   'i',
#   'n',
#   'e',
#   'z',
#   '',
#   '',
#   'L',
#   'l',
#   'a',
#   'n',
#   'e',
#   's,'],
#  ['A',
#   'l',
#   'b',
#   'e',
#   'r',
#   't',
#   'o',
#   '',
#   '',
#   'P',
#   'u',
#   'e',
#   'n',
#   't',
#   'e',
#   's,'],
#  ['A', 'l', 'e', 'c', '', '', 'H', 'a', 'r', 't', 'm', 'a', 'n,'],
#  ['A',
#   'l',
#   'e',
#   'j',
#   'a',
#   'n',
#   'd',
#   'r',
#   'o',
#   '',
#   '',
#   'G',
#   'a',
#   'r',
#   'c',
#   'i',
#   'a,'],
# ...

# %%
classmates= [' '.join(x) for x in classmates]


classmates=' '.join(classmates)
classmates=classmates.replace(",",'\n')
print(classmates)
# Out:
# A d a m   G o m e z
#  A d a m   K r u l l
#  A d a m   T a l b o t
#  a d d i s a l e m   k e m a l
#  A J   M a r t i n e z
#  A b d i e l   M a r t i n e z   L l a n e s
#  A l b e r t o   P u e n t e s
#  A l e c   H a r t m a n
#  A l e j a n d r o   G a r c i a
#  A l e x i a   G a r c e s
#  A l i c i a   G
#  A m a n d a   G o m e z
#  A n d r e w   K i n g
#  A n d r e w   R a c h u i g
#  A n g e l   I .   G o m e z
#  A n n a   V u
#  A n t h o n y   S t r a i n e
#  A r s e n e   B O U N D A O N E
#  A u s t i n   A r a n d a
#  B a r b a r a   M a r q u e s
#  B e n   S m i t h
#  B e t h
#  B e t h a n y   T .
#  B i b e k   M a i n a l i
#  B r a d   G a u v i n
#  B r a e d e n   W r i g h t
#  I n n i s   C o h o r t
#  B r a n d i   R e g e r
#  B r a n d o n   M a r t i n e z
#  B r a n d o n   B r y a n t
#  B r a n d y n   W a t e r m a n
#  B r e n t   S c h r i v e r
#  B r i a n   C l e m e n t s
#  B r o o k e   H o l y o a k
#  C a i t l y n   C a r n e y
# ...
